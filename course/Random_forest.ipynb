# %%
#its a supervised machine learning
#uses mupltiple decision tree
#Ensemble learning techinque
#Oob score(Out of bag sample score)
#we use random forest becaues in decision tree their is overfiting becaues of high veriance and low biase
#so random forest come with low veriance for better prediction

# %%
import pandas as pd
data=pd.read_csv("C:/Users/dheve/OneDrive/Desktop/course/heart_v2_csv - Copy1.csv")
data.head(3)
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   70    1  130         322              1
# 1   67    0  115         564              0
# 2   57    1  124         261              1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            270 non-null    int64
#  1   sex            270 non-null    int64
#  2   BP             270 non-null    int64
#  3   cholestrol     270 non-null    int64
#  4   heart disease  270 non-null    int64
# dtypes: int64(5)
# memory usage: 10.7 KB

# %%
data.isnull().sum()
# Out:
# age              0
# sex              0
# BP               0
# cholestrol       0
# heart disease    0
# dtype: int64

# %%
x=data.drop('heart disease',axis=1)
y=data['heart disease']

# %%
data.columns
# Out:
# Index(['age', 'sex', 'BP', 'cholestrol', 'heart disease'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((189, 4), (81, 4))

# %%
#bagging method
from sklearn.ensemble import RandomForestClassifier

classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True)
#n_jobs=-1 means that all available cores of the CPU will be used, speeding up the process by running computations in parallel.
#Depth refers to the number of splits a tree can make from the root to the leaf. Setting max_depth=5 limits the tree to a depth of 5.
#n_estimators=100:This parameter defines the number of decision trees in the random forest.
#A larger number of estimators generally results in a more accurate and stable model, but also increases computational cost.
#oob_score:It’s a way of estimating the generalization accuracy without needing a separate validation set.
#%%time
classifier_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
# checking the oob score
classifier_rf.oob_score_
#OOB Score is the technique used in bagging algoritham to measure bottom models  error for 
#OOB score represents accuracy of the model
#if oob score represent 95percent,its a excellent model
#0.65 is ok model
#boosting method we can overcome which come under random forest
#high entropy is data are more random or disorderd so entropy is just measure of randomness
#low entrop is data with less random
#information gain is high_entropy - low_entropy
# Out:
# 0.656084656084656
