# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\gt-499\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\gt-499\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\gt-499\anaconda3\lib\site-packages (from xgboost) (1.11.1)

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\GT-499\Downloads\Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x=df.drop(['Gender', 'Spending Score (1-100)'],axis=1)

# %%
x
# Out:
#      CustomerID  Age  Annual Income (k$)
# 0             1   19                  15
# 1             2   21                  15
# 2             3   20                  16
# 3             4   23                  16
# 4             5   31                  17
# ..          ...  ...                 ...
# 195         196   35                 120
# 196         197   45                 126
# 197         198   32                 126
# 198         199   32                 137
# 199         200   30                 137
#
# [200 rows x 3 columns]

# %%
y=df['Spending Score (1-100)']

# %%
y
# Out:
# 0      39
# 1      81
# 2       6
# 3      77
# 4      40
#        ..
# 195    79
# 196    28
# 197    74
# 198    18
# 199    83
# Name: Spending Score (1-100), Length: 200, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((140, 3), (60, 3))

# %%
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()
y_train=Le.fit_transform(y_train)
y_train
# Out:
# array([45, 35, 51, 12, 57, 41, 23, 60, 39,  5, 43, 69,  3, 66, 28, 31, 21,
#        50, 26, 38,  4, 33, 39, 47, 48, 31, 59, 14, 17, 39,  3, 67, 33, 66,
#        71, 13, 51,  4, 44, 40, 25,  2, 25, 70, 33,  9, 11, 37, 27, 23, 16,
#        24, 15, 54, 39, 65, 36, 19, 67, 20, 22, 28, 63,  0, 58, 51, 24, 52,
#        39, 53, 18, 32, 27, 13, 44,  8, 55, 27, 43, 49, 21, 11, 70, 27, 36,
#        11, 68, 37, 26, 29, 12, 61, 31,  1, 55, 31, 53, 53, 46, 34, 61,  3,
#        69, 62, 42, 30, 31, 37, 19, 36, 27, 43, 51, 31, 22,  6, 53, 51, 56,
#        65, 57, 38, 64,  7, 62, 39, 34, 28, 39, 32, 25, 59, 22, 14, 27, 35,
#        10, 34, 64, 42], dtype=int64)

# %%
#MODEL

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
#STEP5:
model = XGBClassifier()
#STEP6:
# fit the model with the training data
#model.fit(x_train,y_train)

# %%
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
predict_train= model.predict(x_train)

# %%
predict_train
# Out:
# array([45, 35, 51, 12, 57, 41, 23, 60, 39,  5, 43, 69,  3, 66, 28, 31, 21,
#        50, 26, 38,  4, 33, 39, 53, 59, 31, 59, 14, 64, 39,  3, 67, 33, 66,
#        44, 13, 51,  4, 44, 40, 25, 11, 25, 70, 33,  9, 11, 37, 27, 23, 14,
#         4, 59, 54, 39, 65, 36, 19, 67, 20, 22, 28, 63,  0, 51, 51, 24, 52,
#        39, 53, 18, 32, 27, 13, 44,  3, 55, 27, 43, 49, 21, 11, 70, 27, 36,
#        11, 24, 37, 26, 29, 12, 61, 31, 11, 55, 31, 53, 53, 53, 34, 61,  3,
#        69, 62, 42, 39, 31, 37, 19, 36, 27, 43, 51, 31, 22, 59, 53, 51, 56,
#        65, 57, 38, 64, 53, 62, 39, 34, 28, 39, 32, 25, 59, 22, 24, 27, 35,
#        10, 34, 64, 42], dtype=int64)

# %%
accuracy_train=accuracy_score(y_train,predict_train)

# %%
accuracy_train
# Out:
# 0.8785714285714286

# %%
#EXCELLENT MODEL
