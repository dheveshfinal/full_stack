# %% [markdown]
# #find relationshing to descibe the corelation between depandent and independent

# %%
#supervised-is structure and predicted using label
#unsupervise-is unstructure and non label,use cluster
#corr(numeric_only=True) the range is b/w 1 and 0 near 1 is more corellation

# %%
import pandas as pd
data=pd.read_csv('C:/Users/dheve/OneDrive/Desktop/course/tips.csv')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(data['tip'])
plt.show()
# Out:
# C:\Users\dheve\AppData\Local\Temp\ipykernel_29664\86919407.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['tip'])

# %%
#ols-odinal least square
#tidle(comparision)~
#statistic_model
#aplication interface
#camparing the sex and smoker
import statsmodels.formula.api as smf
model = smf.ols('total_bill ~ tip', data=data)#specifying ols regression model

# %%
model

# %%
sns.regplot(x='total_bill',y='tip',data=data)#alredy has fit() formula
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#now find the coefficant y=mx+b and (m and c,Beta1 and beta0)
#first fitting the model
model=model.fit()

# %%
model

# %%
model.params
#param is paramiter 
#when tip is zero the model predicted to be 6.7
#and in each unit of total_bill the tip increse by 4.3
# Out:
# Intercept    6.750284
# tip          4.347714
# dtype: float64

# %%
model.rsquared
# Out:
# 0.45661658635167635

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             total_bill   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     203.4
# Date:                Wed, 18 Sep 2024   Prob (F-statistic):           6.69e-34
# Time:                        21:26:10   Log-Likelihood:                -804.77
# No. Observations:                 244   AIC:                             1614.
# Df Residuals:                     242   BIC:                             1621.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.7503      1.006      6.707      0.000       4.768       8.733
# ...

# %%
correlation=data.corr(numeric_only=True)
sns.heatmap(correlation,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#multiplr regression
import pandas as pd
data=pd.read_csv('C:/Users/dheve/OneDrive/Desktop/course/50_Startups.csv')
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.shape
# Out:
# (50, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
import seaborn as sns
sns.boxplot(x='State',y='Profit',data=data)
# Out:
# <Axes: xlabel='State', ylabel='Profit'>

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,4]
#both belong to pandas
#iloc is for values and loc is for label
x
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Marketing Spend'>

# %%
#reading the outlyer
df = pd.DataFrame(data)
def find_outliers(df):
    outliers = {}
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors='coerce')
        clean_data = df[column].dropna()
        if not clean_data.empty:
            Q1 = clean_data.quantile(0.25)
            Q3 = clean_data.quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            outlier_values = clean_data[(clean_data < lower_bound) | (clean_data > upper_bound)]
            outliers[column] = outlier_values.tolist()
    return outliers
outliers = find_outliers(df)
print(outliers)
# Out:
# {'R&D Spend': [], 'Administration': [], 'Marketing Spend': [], 'Profit': [14681.4]}

# %%
#catagorical value converted to numerical(0,1) for analysing in machin learning
states=pd.get_dummies(x['State'],drop_first=True)
states = states.astype(int)
x=x.drop('State',axis=1)
#drop_first first catagorys is dropped

# %%
# Assuming states is a DataFrame with True/False values
# Out:
#     Florida  New York
# 0         0         1
# 1         0         0
# 2         1         0
# 3         0         1
# 4         1         0
# 5         0         1
# 6         0         0
# 7         1         0
# 8         0         1
# 9         0         0
# 10        1         0
# 11        0         0
# 12        1         0
# 13        0         0
# 14        1         0
# 15        0         1
# 16        0         0
# 17        0         1
# 18        1         0
# 19        0         1
# 20        0         0
# 21        0         1
# 22        1         0
# 23        1         0
# 24        0         1
# 25        0         0
# 26        1         0
# 27        0         1
# 28        1         0
# 29        0         1
# 30        1         0
# 31        0         1
# 32        0         0
# 33        1         0
# 34        0         0
# 35        0         1
# 36        1         0
# 37        0         0
# 38        0         1
# 39        0         0
# ...

# %%
result = pd.concat([x, states], axis=1)

# %%
result
# Out:
#     R&D Spend  Administration  Marketing Spend  Florida  New York
# 0   165349.20       136897.80        471784.10        0         1
# 1   162597.70       151377.59        443898.53        0         0
# 2   153441.51       101145.55        407934.54        1         0
# 3   144372.41       118671.85        383199.62        0         1
# 4   142107.34        91391.77        366168.42        1         0
# 5   131876.90        99814.71        362861.36        0         1
# 6   134615.46       147198.87        127716.82        0         0
# 7   130298.13       145530.06        323876.68        1         0
# 8   120542.52       148718.95        311613.29        0         1
# 9   123334.88       108679.17        304981.62        0         0
# 10  101913.08       110594.11        229160.95        1         0
# 11  100671.96        91790.61        249744.55        0         0
# 12   93863.75       127320.38        249839.44        1         0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
pt=LinearRegression()
pt.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=pt.predict(x_test)
y_pred
# Out:
# array([126703.02716461,  84894.75081556,  98893.41815974,  46501.70815036,
#        129128.39734381,  50992.69486261, 109016.5536578 , 100878.4641454 ,
#         97700.59638629, 113106.15292226])

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse=mean_squared_error(y_test,y_pred)
r2_square=r2_score(y_test,y_pred)
r2_square
# Out:
# 0.900065308303732
